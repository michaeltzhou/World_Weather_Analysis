# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | ambovombe
# Processing Record 5 of Set 1 | bogorodskoye
# Processing Record 6 of Set 1 | athabasca
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | tommot
# Processing Record 9 of Set 1 | channel-port aux basques
# Processing Record 10 of Set 1 | rocha
# Processing Record 11 of Set 1 | tabuk
# Processing Record 12 of Set 1 | teya
# Processing Record 13 of Set 1 | jalu
# Processing Record 14 of Set 1 | nur
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | bosaso
# Processing Record 23 of Set 1 | pareora
# Processing Record 24 of Set 1 | barra da estiva
# Processing Record 25 of Set 1 | sokna
# Processing Record 26 of Set 1 | bereda
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | kruisfontein
# Processing Record 30 of Set 1 | avera
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | rawson
# Processing Record 33 of Set 1 | adolfo lopez mateos
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | bambanglipuro
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | dubbo
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | maunabo
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | sainte-rose
# Processing Record 42 of Set 1 | sinjai
# Processing Record 43 of Set 1 | half moon bay
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 1 | constitucion
# Processing Record 47 of Set 1 | nikolskoye
# Processing Record 48 of Set 1 | vila franca do campo
# Processing Record 49 of Set 1 | loiza
# Processing Record 50 of Set 1 | villamontes
# Processing Record 1 of Set 2 | salisbury
# Processing Record 2 of Set 2 | williston
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | sinop
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | cabra
# Processing Record 7 of Set 2 | mehamn
# Processing Record 8 of Set 2 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | kodiak
# Processing Record 11 of Set 2 | inirida
# Processing Record 12 of Set 2 | kitgum
# Processing Record 13 of Set 2 | vestmanna
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | san patricio
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | bambous virieux
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | kupino
# Processing Record 21 of Set 2 | coari
# Processing Record 22 of Set 2 | kharp
# Processing Record 23 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 2 | roald
# Processing Record 25 of Set 2 | saint pete beach
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | carnarvon
# Processing Record 28 of Set 2 | wucheng
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | solnechnyy
# Processing Record 32 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | urumqi
# Processing Record 36 of Set 2 | palu
# Processing Record 37 of Set 2 | vestmannaeyjar
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | mezhdurechensk
# Processing Record 41 of Set 2 | san miguel
# Processing Record 42 of Set 2 | port hardy
# Processing Record 43 of Set 2 | mar del plata
# Processing Record 44 of Set 2 | yeppoon
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | amahai
# Processing Record 48 of Set 2 | soure
# Processing Record 49 of Set 2 | kaitangata
# Processing Record 50 of Set 2 | erenhot
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | soyo
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | puerto del rosario
# Processing Record 6 of Set 3 | mitu
# Processing Record 7 of Set 3 | san fernando
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | watsa
# Processing Record 10 of Set 3 | sungairaya
# Processing Record 11 of Set 3 | beringovskiy
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | fatikchhari
# City not found. Skipping...
# Processing Record 18 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | tuatapere
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | biak
# Processing Record 24 of Set 3 | vanimo
# Processing Record 25 of Set 3 | verkh-usugli
# Processing Record 26 of Set 3 | kahului
# Processing Record 27 of Set 3 | qasigiannguit
# Processing Record 28 of Set 3 | llodio
# Processing Record 29 of Set 3 | hobart
# Processing Record 30 of Set 3 | kirakira
# Processing Record 31 of Set 3 | poronaysk
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | whitianga
# Processing Record 34 of Set 3 | sitka
# Processing Record 35 of Set 3 | nanortalik
# Processing Record 36 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 3 | conakry
# Processing Record 38 of Set 3 | ouagadougou
# Processing Record 39 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 3 | azad shahr
# Processing Record 41 of Set 3 | dessalines
# Processing Record 42 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 3 | saint-augustin
# Processing Record 44 of Set 3 | nagato
# Processing Record 45 of Set 3 | husavik
# Processing Record 46 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | hobyo
# Processing Record 49 of Set 3 | shaartuz
# City not found. Skipping...
# Processing Record 50 of Set 3 | cayenne
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | ban mo
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | quesnel
# Processing Record 5 of Set 4 | paamiut
# Processing Record 6 of Set 4 | guozhen
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | jiuquan
# Processing Record 9 of Set 4 | saint anthony
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | east london
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | faya
# Processing Record 14 of Set 4 | crib point
# Processing Record 15 of Set 4 | salta
# Processing Record 16 of Set 4 | cidreira
# Processing Record 17 of Set 4 | biltine
# Processing Record 18 of Set 4 | alekseyevsk
# Processing Record 19 of Set 4 | posse
# Processing Record 20 of Set 4 | hilo
# Processing Record 21 of Set 4 | calabozo
# Processing Record 22 of Set 4 | lundazi
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | san juan
# Processing Record 25 of Set 4 | coos bay
# Processing Record 26 of Set 4 | frankfort
# Processing Record 27 of Set 4 | barrow
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | khandyga
# Processing Record 30 of Set 4 | severo-kurilsk
# Processing Record 31 of Set 4 | boende
# Processing Record 32 of Set 4 | popondetta
# Processing Record 33 of Set 4 | zyryanka
# Processing Record 34 of Set 4 | maarianhamina
# Processing Record 35 of Set 4 | marrakesh
# Processing Record 36 of Set 4 | ladario
# Processing Record 37 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 4 | komsomolskiy
# Processing Record 39 of Set 4 | mocuba
# Processing Record 40 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 4 | padang
# Processing Record 42 of Set 4 | los llanos de aridane
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | la peca
# Processing Record 45 of Set 4 | sadovoye
# Processing Record 46 of Set 4 | coihaique
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | constantine
# Processing Record 49 of Set 4 | mogadishu
# Processing Record 50 of Set 4 | monrovia
# Processing Record 1 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 3 of Set 5 | cockburn town
# Processing Record 4 of Set 5 | havoysund
# Processing Record 5 of Set 5 | valparaiso
# Processing Record 6 of Set 5 | vila
# Processing Record 7 of Set 5 | maniitsoq
# Processing Record 8 of Set 5 | lodwar
# Processing Record 9 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 5 | zambezi
# Processing Record 11 of Set 5 | udachnyy
# Processing Record 12 of Set 5 | saint augustine
# Processing Record 13 of Set 5 | araouane
# Processing Record 14 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 5 | hasaki
# Processing Record 16 of Set 5 | laguna
# Processing Record 17 of Set 5 | bandarbeyla
# Processing Record 18 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 5 | panuco
# Processing Record 20 of Set 5 | bac lieu
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | ritchie
# Processing Record 23 of Set 5 | iqaluit
# Processing Record 24 of Set 5 | pompeu
# Processing Record 25 of Set 5 | ponta do sol
# Processing Record 26 of Set 5 | san carlos de bariloche
# Processing Record 27 of Set 5 | cherskiy
# Processing Record 28 of Set 5 | lipetsk
# Processing Record 29 of Set 5 | lavrentiya
# Processing Record 30 of Set 5 | sibolga
# Processing Record 31 of Set 5 | marsh harbour
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | butembo
# Processing Record 34 of Set 5 | vanino
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | shakawe
# Processing Record 38 of Set 5 | kamarai
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | catuday
# Processing Record 41 of Set 5 | mount gambier
# Processing Record 42 of Set 5 | beihai
# Processing Record 43 of Set 5 | walvis bay
# Processing Record 44 of Set 5 | mangrol
# Processing Record 45 of Set 5 | paraiso
# Processing Record 46 of Set 5 | viedma
# Processing Record 47 of Set 5 | diamantino
# Processing Record 48 of Set 5 | tocantinopolis
# City not found. Skipping...
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | poum
# Processing Record 1 of Set 6 | regente feijo
# Processing Record 2 of Set 6 | salinopolis
# Processing Record 3 of Set 6 | zadonsk
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | buon me thuot
# City not found. Skipping...
# Processing Record 6 of Set 6 | yar-sale
# Processing Record 7 of Set 6 | krasnokamensk
# Processing Record 8 of Set 6 | kamaishi
# Processing Record 9 of Set 6 | khatanga
# Processing Record 10 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 11 of Set 6 | salalah
# Processing Record 12 of Set 6 | tupik
# Processing Record 13 of Set 6 | marystown
# Processing Record 14 of Set 6 | zhangye
# Processing Record 15 of Set 6 | sept-iles
# Processing Record 16 of Set 6 | pak phanang
# Processing Record 17 of Set 6 | novyy yarychiv
# Processing Record 18 of Set 6 | ormara
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | puerto escondido
# Processing Record 21 of Set 6 | yudong
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | vila velha
# Processing Record 24 of Set 6 | bethel
# Processing Record 25 of Set 6 | toamasina
# Processing Record 26 of Set 6 | saint-francois
# Processing Record 27 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 6 | victor harbor
# Processing Record 29 of Set 6 | melur
# Processing Record 30 of Set 6 | palmer
# Processing Record 31 of Set 6 | nhulunbuy
# Processing Record 32 of Set 6 | hasanpur
# Processing Record 33 of Set 6 | miquelon
# Processing Record 34 of Set 6 | georgetown
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | nanakuli
# Processing Record 38 of Set 6 | beipiao
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | safakulevo
# Processing Record 41 of Set 6 | tunceli
# Processing Record 42 of Set 6 | izazi
# Processing Record 43 of Set 6 | joutseno
# Processing Record 44 of Set 6 | hithadhoo
# Processing Record 45 of Set 6 | rio grande
# Processing Record 46 of Set 6 | kashary
# Processing Record 47 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 6 | werda
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | esperance
# Processing Record 1 of Set 7 | teahupoo
# Processing Record 2 of Set 7 | pevek
# Processing Record 3 of Set 7 | alihe
# Processing Record 4 of Set 7 | great yarmouth
# Processing Record 5 of Set 7 | bulawayo
# Processing Record 6 of Set 7 | ouallam
# Processing Record 7 of Set 7 | opuwo
# Processing Record 8 of Set 7 | sorrento
# Processing Record 9 of Set 7 | kijang
# Processing Record 10 of Set 7 | lewiston
# Processing Record 11 of Set 7 | merauke
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | sakakah
# Processing Record 14 of Set 7 | kimberley
# Processing Record 15 of Set 7 | touros
# Processing Record 16 of Set 7 | saryg-sep
# Processing Record 17 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | samarai
# Processing Record 19 of Set 7 | aswan
# Processing Record 20 of Set 7 | saint-pierre
# Processing Record 21 of Set 7 | alpena
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | litovko
# Processing Record 25 of Set 7 | roros
# Processing Record 26 of Set 7 | arinos
# Processing Record 27 of Set 7 | bud
# Processing Record 28 of Set 7 | the valley
# Processing Record 29 of Set 7 | paoua
# Processing Record 30 of Set 7 | inhambane
# Processing Record 31 of Set 7 | sukhumi
# Processing Record 32 of Set 7 | ocampo
# Processing Record 33 of Set 7 | kabinda
# Processing Record 34 of Set 7 | kommunisticheskiy
# Processing Record 35 of Set 7 | sao filipe
# Processing Record 36 of Set 7 | plouzane
# Processing Record 37 of Set 7 | haines junction
# Processing Record 38 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 7 | acarau
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 7 | back mountain
# Processing Record 43 of Set 7 | harper
# Processing Record 44 of Set 7 | acapulco
# Processing Record 45 of Set 7 | kisszallas
# Processing Record 46 of Set 7 | bria
# Processing Record 47 of Set 7 | richards bay
# Processing Record 48 of Set 7 | adrar
# Processing Record 49 of Set 7 | shenjiamen
# Processing Record 50 of Set 7 | maragogi
# Processing Record 1 of Set 8 | sistranda
# Processing Record 2 of Set 8 | sinnamary
# Processing Record 3 of Set 8 | bukama
# Processing Record 4 of Set 8 | marawi
# Processing Record 5 of Set 8 | comodoro rivadavia
# Processing Record 6 of Set 8 | lagoa
# Processing Record 7 of Set 8 | panaba
# Processing Record 8 of Set 8 | kristiinankaupunki
# Processing Record 9 of Set 8 | palladam
# Processing Record 10 of Set 8 | dalianwan
# Processing Record 11 of Set 8 | saurimo
# Processing Record 12 of Set 8 | rovinj
# Processing Record 13 of Set 8 | chuy
# Processing Record 14 of Set 8 | flinders
# Processing Record 15 of Set 8 | kars
# Processing Record 16 of Set 8 | saint-joseph
# Processing Record 17 of Set 8 | guarda
# Processing Record 18 of Set 8 | hami
# Processing Record 19 of Set 8 | uyuni
# Processing Record 20 of Set 8 | kupang
# Processing Record 21 of Set 8 | kaduqli
# Processing Record 22 of Set 8 | narsaq
# Processing Record 23 of Set 8 | tsumeb
# Processing Record 24 of Set 8 | ewa beach
# Processing Record 25 of Set 8 | xining
# Processing Record 26 of Set 8 | port macquarie
# Processing Record 27 of Set 8 | alice springs
# Processing Record 28 of Set 8 | kenai
# Processing Record 29 of Set 8 | pisco
# Processing Record 30 of Set 8 | cabo san lucas
# Processing Record 31 of Set 8 | bonthe
# Processing Record 32 of Set 8 | namanga
# Processing Record 33 of Set 8 | klaksvik
# Processing Record 34 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 35 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 8 | kloulklubed
# Processing Record 37 of Set 8 | timizart
# Processing Record 38 of Set 8 | aykhal
# Processing Record 39 of Set 8 | vostok
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | helena
# Processing Record 42 of Set 8 | qorveh
# Processing Record 43 of Set 8 | sebinkarahisar
# Processing Record 44 of Set 8 | snezhnogorsk
# Processing Record 45 of Set 8 | zenzeli
# Processing Record 46 of Set 8 | pontianak
# Processing Record 47 of Set 8 | sao jose de piranhas
# Processing Record 48 of Set 8 | aklavik
# Processing Record 49 of Set 8 | amapa
# Processing Record 50 of Set 8 | leningradskiy
# Processing Record 1 of Set 9 | koslan
# Processing Record 2 of Set 9 | adamas
# Processing Record 3 of Set 9 | juba
# Processing Record 4 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 9 | aginskoye
# Processing Record 7 of Set 9 | hambantota
# Processing Record 8 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 9 | dudinka
# Processing Record 10 of Set 9 | nouadhibou
# Processing Record 11 of Set 9 | fortuna
# Processing Record 12 of Set 9 | agadir
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | fukue
# Processing Record 15 of Set 9 | navoi
# Processing Record 16 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 9 | aquiraz
# Processing Record 18 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 9 | olavarria
# Processing Record 20 of Set 9 | kidal
# Processing Record 21 of Set 9 | tacoronte
# Processing Record 22 of Set 9 | ariquemes
# Processing Record 23 of Set 9 | de-kastri
# Processing Record 24 of Set 9 | san angelo
# Processing Record 25 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 9 | smirnykh
# Processing Record 27 of Set 9 | rio gallegos
# Processing Record 28 of Set 9 | ostrovnoy
# Processing Record 29 of Set 9 | kieta
# Processing Record 30 of Set 9 | swellendam
# Processing Record 31 of Set 9 | stuttgart
# Processing Record 32 of Set 9 | dipkarpaz
# City not found. Skipping...
# Processing Record 33 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 9 | asau
# Processing Record 35 of Set 9 | concarneau
# Processing Record 36 of Set 9 | natal
# Processing Record 37 of Set 9 | zima
# Processing Record 38 of Set 9 | bose
# Processing Record 39 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 9 | brazzaville
# Processing Record 41 of Set 9 | nichinan
# Processing Record 42 of Set 9 | makakilo city
# Processing Record 43 of Set 9 | brigham city
# Processing Record 44 of Set 9 | oktyabrskoye
# Processing Record 45 of Set 9 | komatipoort
# Processing Record 46 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 9 | namatanai
# Processing Record 48 of Set 9 | wanaka
# Processing Record 49 of Set 9 | kandrian
# Processing Record 50 of Set 9 | arkhipo-osipovka
# Processing Record 1 of Set 10 | chippewa falls
# Processing Record 2 of Set 10 | coquimbo
# Processing Record 3 of Set 10 | punta alta
# Processing Record 4 of Set 10 | oltu
# Processing Record 5 of Set 10 | olkhovatka
# Processing Record 6 of Set 10 | yatou
# Processing Record 7 of Set 10 | putineiu
# Processing Record 8 of Set 10 | pueblo nuevo
# Processing Record 9 of Set 10 | port hedland
# Processing Record 10 of Set 10 | baykit
# Processing Record 11 of Set 10 | shatoy
# Processing Record 12 of Set 10 | stutterheim
# Processing Record 13 of Set 10 | camindangan
# Processing Record 14 of Set 10 | uvinza
# Processing Record 15 of Set 10 | praia da vitoria
# Processing Record 16 of Set 10 | hamilton
# Processing Record 17 of Set 10 | nchelenge
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | roanoke rapids
# Processing Record 20 of Set 10 | port elizabeth
# Processing Record 21 of Set 10 | iquique
# Processing Record 22 of Set 10 | behbahan
# Processing Record 23 of Set 10 | taoudenni
# Processing Record 24 of Set 10 | senanga
# Processing Record 25 of Set 10 | malumfashi
# Processing Record 26 of Set 10 | saqqez
# Processing Record 27 of Set 10 | parsabad
# Processing Record 28 of Set 10 | ambilobe
# Processing Record 29 of Set 10 | sonoita
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | middlebury
# Processing Record 32 of Set 10 | airai
# Processing Record 33 of Set 10 | vulcanesti
# Processing Record 34 of Set 10 | isangel
# Processing Record 35 of Set 10 | lagos
# Processing Record 36 of Set 10 | mardin
# Processing Record 37 of Set 10 | tarata
# Processing Record 38 of Set 10 | watertown
# Processing Record 39 of Set 10 | hovd
# Processing Record 40 of Set 10 | lardos
# Processing Record 41 of Set 10 | port moresby
# Processing Record 42 of Set 10 | pangnirtung
# Processing Record 43 of Set 10 | norheimsund
# Processing Record 44 of Set 10 | vanavara
# Processing Record 45 of Set 10 | nowy dwor gdanski
# Processing Record 46 of Set 10 | talnakh
# Processing Record 47 of Set 10 | bintulu
# Processing Record 48 of Set 10 | burica
# City not found. Skipping...
# Processing Record 49 of Set 10 | corbu
# Processing Record 50 of Set 10 | terrace
# Processing Record 1 of Set 11 | shimoda
# Processing Record 2 of Set 11 | eldorado
# Processing Record 3 of Set 11 | buritizeiro
# Processing Record 4 of Set 11 | ponta delgada
# Processing Record 5 of Set 11 | north bend
# Processing Record 6 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 7 of Set 11 | two rivers
# Processing Record 8 of Set 11 | san mateo del mar
# Processing Record 9 of Set 11 | isiro
# Processing Record 10 of Set 11 | las cruces
# Processing Record 11 of Set 11 | dorado
# Processing Record 12 of Set 11 | yenagoa
# Processing Record 13 of Set 11 | sturgeon bay
# Processing Record 14 of Set 11 | nioro
# Processing Record 15 of Set 11 | elat
# Processing Record 16 of Set 11 | mawlaik
# Processing Record 17 of Set 11 | vung tau
# Processing Record 18 of Set 11 | baruun-urt
# Processing Record 19 of Set 11 | taltal
# Processing Record 20 of Set 11 | calama
# Processing Record 21 of Set 11 | alta floresta
# Processing Record 22 of Set 11 | darasun
# Processing Record 23 of Set 11 | tessalit
# Processing Record 24 of Set 11 | huarmey
# Processing Record 25 of Set 11 | goderich
# Processing Record 26 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 11 | mkokotoni
# Processing Record 28 of Set 11 | tsogni
# Processing Record 29 of Set 11 | brae
# Processing Record 30 of Set 11 | tazovskiy
# Processing Record 31 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 32 of Set 11 | pringsewu
# Processing Record 33 of Set 11 | teguise
# Processing Record 34 of Set 11 | itarema
# Processing Record 35 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 11 | ishinomaki
# Processing Record 37 of Set 11 | necochea
# Processing Record 38 of Set 11 | dingle
# Processing Record 39 of Set 11 | cap malheureux
# Processing Record 40 of Set 11 | pangkalanbuun
# Processing Record 41 of Set 11 | burns lake
# Processing Record 42 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 11 | qaqortoq
# Processing Record 44 of Set 11 | tamandare
# Processing Record 45 of Set 11 | saint-georges
# Processing Record 46 of Set 11 | barroualie
# City not found. Skipping...
# Processing Record 47 of Set 11 | gorontalo
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | thiers
# Processing Record 50 of Set 11 | bam
# Processing Record 1 of Set 12 | yaan
# Processing Record 2 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 12 | sarkand
# Processing Record 4 of Set 12 | montijo
# Processing Record 5 of Set 12 | guarapari
# Processing Record 6 of Set 12 | troitskoye
# Processing Record 7 of Set 12 | caconda
# Processing Record 8 of Set 12 | melita
# Processing Record 9 of Set 12 | punta de piedra
# Processing Record 10 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 12 | slave lake
# Processing Record 12 of Set 12 | muroto
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | port-gentil
# Processing Record 15 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 12 | winnemucca
# Processing Record 17 of Set 12 | sechura
# Processing Record 18 of Set 12 | ishigaki
# Processing Record 19 of Set 12 | vikulovo
# Processing Record 20 of Set 12 | moussoro
# Processing Record 21 of Set 12 | rumoi
# Processing Record 22 of Set 12 | amantea
# Processing Record 23 of Set 12 | ardahan
# Processing Record 24 of Set 12 | almaznyy
# Processing Record 25 of Set 12 | gamba
# Processing Record 26 of Set 12 | benghazi
# Processing Record 27 of Set 12 | piacabucu
# Processing Record 28 of Set 12 | ongandjera
# Processing Record 29 of Set 12 | berlevag
# Processing Record 30 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 12 | mersing
# Processing Record 32 of Set 12 | sulina
# Processing Record 33 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 34 of Set 12 | banyo
# Processing Record 35 of Set 12 | nara
# Processing Record 36 of Set 12 | leeton
# Processing Record 37 of Set 12 | sivaki
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | esil
# Processing Record 40 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 41 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 12 | hervey bay
# Processing Record 43 of Set 12 | hay river
# Processing Record 44 of Set 12 | qixia
# Processing Record 45 of Set 12 | ambanja
# Processing Record 46 of Set 12 | lalmohan
# Processing Record 47 of Set 12 | polohy
# Processing Record 48 of Set 12 | tautira
# Processing Record 49 of Set 12 | elliot lake
# Processing Record 50 of Set 12 | byron bay
# Processing Record 1 of Set 13 | durres
# Processing Record 2 of Set 13 | bealanana
# Processing Record 3 of Set 13 | sola
# Processing Record 4 of Set 13 | bathsheba
# Processing Record 5 of Set 13 | iracoubo
# Processing Record 6 of Set 13 | sosnovskoye
# Processing Record 7 of Set 13 | zlocieniec
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 547

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                   Ushuaia -54.8000  -68.3000     46.06        61
# 1                   Mataura -46.1927  168.8643     51.48        85
# 2              Puerto Ayora  -0.7393  -90.3518     85.96        84
# 3                 Ambovombe -25.1667   46.0833     70.65        95
# 4              Bogorodskoye  56.5500   37.8833     27.12        97
# 5                 Athabasca  54.7169 -113.2854     16.21        69
# 6                    Atuona  -9.8000 -139.0333     80.06        79
# 7                    Tommot  58.9564  126.2925     22.55        89
# 8  Channel-Port Aux Basques  47.5702  -59.1367     21.04        68
# 9                     Rocha -34.4833  -54.3333     74.82        68
#
#    Cloudiness  Wind Speed Country                 Date
# 0          75       20.71      AR  2023-03-04 21:58:08
# 1          83        1.12      NZ  2023-03-04 21:59:18
# 2          81       10.00      EC  2023-03-04 22:00:09
# 3         100        5.17      MG  2023-03-04 22:00:09
# 4         100        8.01      RU  2023-03-04 22:00:10
# 5         100       11.27      CA  2023-03-04 22:00:10
# 6          13       12.37      PF  2023-03-04 22:00:11
# 7         100       12.84      RU  2023-03-04 22:00:11
# 8          99       20.89      CA  2023-03-04 22:00:12
# 9          18        7.02      UY  2023-03-04 22:00:13

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column]

# Display sample data
city_data_df.head(10)
# Out:
#                        City Country                 Date      Lat       Lng  \
# 0                   Ushuaia      AR  2023-03-04 21:58:08 -54.8000  -68.3000
# 1                   Mataura      NZ  2023-03-04 21:59:18 -46.1927  168.8643
# 2              Puerto Ayora      EC  2023-03-04 22:00:09  -0.7393  -90.3518
# 3                 Ambovombe      MG  2023-03-04 22:00:09 -25.1667   46.0833
# 4              Bogorodskoye      RU  2023-03-04 22:00:10  56.5500   37.8833
# 5                 Athabasca      CA  2023-03-04 22:00:10  54.7169 -113.2854
# 6                    Atuona      PF  2023-03-04 22:00:11  -9.8000 -139.0333
# 7                    Tommot      RU  2023-03-04 22:00:11  58.9564  126.2925
# 8  Channel-Port Aux Basques      CA  2023-03-04 22:00:12  47.5702  -59.1367
# 9                     Rocha      UY  2023-03-04 22:00:13 -34.4833  -54.3333
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     46.06        61          75       20.71
# 1     51.48        85          83        1.12
# 2     85.96        84          81       10.00
# 3     70.65        95         100        5.17
# 4     27.12        97         100        8.01
# 5     16.21        69         100       11.27
# 6     80.06        79          13       12.37
# 7     22.55        89         100       12.84
# 8     21.04        68          99       20.89
# 9     74.82        68          18        7.02

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
import os
# Set the output file name
output_file = 'Weather_Database/WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City_ID")
